# %%
# Python3 program to find the most 
# frequent element in an array.
 
def mostFrequent():
    arr=sum([rd.sample(range(1000),100) for i in range(100)],[]) 
    n=len(arr)
 
    # Sort the array
    arr.sort()
 
    # find the max frequency using
    # linear traversal
    max_count = 1; res = arr[0]; curr_count = 1
     
    for i in range(1, n): 
        if (arr[i] == arr[i - 1]):
            curr_count += 1
             
        else :
            if (curr_count > max_count): 
                max_count = curr_count
                res = arr[i - 1]
             
            curr_count = 1
     
    # If last element is most frequent
    if (curr_count > max_count):
     
        max_count = curr_count
        res = arr[n - 1]
     
    return res

# %%
import random as rd
rd.seed(100)

# %%
# %timeit mostFrequent()
# Out:
# 14.3 ms ± 266 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# Driver Code
arr = [0,1,9, 5,3,5,2,9,8,4,4,4,4, 1, 3, 2,1,9,9,9]*900 
n = len(arr)
print(mostFrequent(arr))
 
# This code is contributed by Smitha Dinesh Semwal.
# Out:
# 9

# %%
def use_dict():
    arr=sum([rd.sample(range(1000),100) for i in range(100)],[]) 
    
    freq={}
    
    for i in arr:
        freq[i] = freq.get(i,0)+1
        
    return freq,max(freq,key=freq.get)

# %%
# %timeit use_dict()
# Out:
# 12.6 ms ± 54.8 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit mostFrequent(arr)
# Out:
# 2.53 ms ± 20.8 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
from collections import Counter
import numpy as np

# %%
# %lprun -f use_dict use_dict()

# %%
# %timeit Counter(alist).most_common(1)[0][0]
# Out:
# 640 µs ± 5.07 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %load_ext line_profiler

# %%
def np_count(arr):
    value,count=np.unique(arr,return_counts=True)
    ind=np.argmax(count)
    return value[ind]

# %%
# %timeit np_count(alist)
# Out:
# 965 µs ± 22.8 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
def np_bincount(arr):
# Out:
#   File "<ipython-input-39-2b017159b4f2>", line 1
#     def np_bincount(arr)
#                         ^
# SyntaxError: invalid syntax

# %%
np.bincount(arr)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-2821a44bc0ac> in <module>()
# ----> 1 np.bincount(arr)
#
# ValueError: invalid literal for int() with base 10: 'a'

# %%
# %lprun -f mostFrequent mostFrequent()

# %%
# %lprun -f use_dict use_dict()

# %%
def prof_function():
    x=10*20
    y=10+x
    return (y)

# %%
# %lprun -f prof_function prof_function()

# %%
alist=sum([rd.sample(range(1000),100) for i in range(100)],[])

# %%
alist
# Out:
# [343,
#  235,
#  316,
#  859,
#  786,
#  208,
#  983,
#  182,
#  144,
#  193,
#  914,
#  355,
#  378,
#  641,
#  419,
#  854,
#  215,
#  412,
#  979,
#  472,
#  568,
#  282,
#  922,
#  811,
#  837,
#  384,
#  164,
#  877,
#  664,
#  653,
#  127,
#  184,
#  5,
#  617,
#  405,
#  151,
#  792,
#  871,
#  579,
#  166,
#  197,
#  171,
#  861,
#  26,
#  935,
#  681,
#  242,
#  458,
#  818,
#  970,
#  944,
#  923,
#  396,
#  129,
#  638,
#  567,
#  775,
#  53,
#  623,
#  253,
#  734,
#  633,
#  793,
#  519,
#  731,
#  296,
#  706,
#  604,
#  346,
#  540,
#  698,
#  351,
#  555,
#  874,
#  371,
#  495,
#  411,
#  779,
#  63,
#  833,
#  103,
#  911,
#  307,
#  667,
#  444,
#  258,
#  245,
#  867,
#  843,
#  723,
#  955,
#  447,
#  785,
#  525,
#  820,
#  505,
#  596,
#  260,
#  150,
#  59,
#  692,
#  599,
#  882,
#  334,
#  168,
#  55,
#  771,
#  281,
#  723,
#  712,
#  123,
#  735,
#  51,
#  800,
#  609,
#  907,
#  224,
#  984,
#  317,
#  537,
#  636,
#  221,
#  666,
#  823,
#  766,
#  744,
# ...
